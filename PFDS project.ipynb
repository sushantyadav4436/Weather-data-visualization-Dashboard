# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
df = pd.read_csv("C:\\Users\\admin\\Downloads\\weather.csv")
df
# Out:
#        Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                    0.00  2016-01-03           1             3       2016
# 1                    0.00  2016-01-03           1             3       2016
# 2                    0.16  2016-01-03           1             3       2016
# 3                    0.00  2016-01-03           1             3       2016
# 4                    0.01  2016-01-03           1             3       2016
# ...                   ...         ...         ...           ...        ...
# 16738                0.08  2017-01-01           1             1       2017
# 16739                0.00  2017-01-01           1             1       2017
# 16740                0.00  2017-01-01           1             1       2017
# 16741                0.06  2017-01-01           1             1       2017
# 16742                0.10  2017-01-01           1             1       2017
#
#       Station.City Station.Code Station.Location Station.State  \
# ...

# %%
df.shape
# Out:
# (16743, 14)

# %%
df.info
# Out:
# <bound method DataFrame.info of        Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                    0.00  2016-01-03           1             3       2016
# 1                    0.00  2016-01-03           1             3       2016
# 2                    0.16  2016-01-03           1             3       2016
# 3                    0.00  2016-01-03           1             3       2016
# 4                    0.01  2016-01-03           1             3       2016
# ...                   ...         ...         ...           ...        ...
# 16738                0.08  2017-01-01           1             1       2017
# 16739                0.00  2017-01-01           1             1       2017
# 16740                0.00  2017-01-01           1             1       2017
# 16741                0.06  2017-01-01           1             1       2017
# 16742                0.10  2017-01-01           1             1       2017
#
# ...

# %%
df.isnull()
# Out:
#        Data.Precipitation  Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                   False      False       False         False      False
# 1                   False      False       False         False      False
# 2                   False      False       False         False      False
# 3                   False      False       False         False      False
# 4                   False      False       False         False      False
# ...                   ...        ...         ...           ...        ...
# 16738               False      False       False         False      False
# 16739               False      False       False         False      False
# 16740               False      False       False         False      False
# 16741               False      False       False         False      False
# 16742               False      False       False         False      False
#
#        Station.City  Station.Code  Station.Location  Station.State  \
# ...

# %%
df.isnull().sum()
# Out:
# Data.Precipitation           0
# Date.Full                    0
# Date.Month                   0
# Date.Year                    0
# Station.City                 0
# Station.Code                 0
# Station.Location             0
# Station.State                0
# Data.Temperature.Avg Temp    0
# Data.Temperature.Max Temp    0
# Data.Temperature.Min Temp    0
# Data.Wind.Direction          0
# Data.Wind.Speed              0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Data.Precipitation', 'Date.Full', 'Date.Month', 'Date.Year',
#        'Station.City', 'Station.Code', 'Station.Location', 'Station.State',
#        'Data.Temperature.Avg Temp', 'Data.Temperature.Max Temp',
#        'Data.Temperature.Min Temp', 'Data.Wind.Direction', 'Data.Wind.Speed'],
#       dtype='object')

# %%
df.dropna()
# Out:
#        Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                    0.00  2016-01-03           1             3       2016
# 1                    0.00  2016-01-03           1             3       2016
# 2                    0.16  2016-01-03           1             3       2016
# 3                    0.00  2016-01-03           1             3       2016
# 4                    0.01  2016-01-03           1             3       2016
# ...                   ...         ...         ...           ...        ...
# 16738                0.08  2017-01-01           1             1       2017
# 16739                0.00  2017-01-01           1             1       2017
# 16740                0.00  2017-01-01           1             1       2017
# 16741                0.06  2017-01-01           1             1       2017
# 16742                0.10  2017-01-01           1             1       2017
#
#       Station.City Station.Code Station.Location Station.State  \
# ...

# %%
df.rename(columns={"Data.Precipitation": "Precipitation"})
df.rename(columns={"Data.Temperature.Avg Temp": "Average Temprature"})
# Out:
#        Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                    0.00  2016-01-03           1             3       2016
# 1                    0.00  2016-01-03           1             3       2016
# 2                    0.16  2016-01-03           1             3       2016
# 3                    0.00  2016-01-03           1             3       2016
# 4                    0.01  2016-01-03           1             3       2016
# ...                   ...         ...         ...           ...        ...
# 16738                0.08  2017-01-01           1             1       2017
# 16739                0.00  2017-01-01           1             1       2017
# 16740                0.00  2017-01-01           1             1       2017
# 16741                0.06  2017-01-01           1             1       2017
# 16742                0.10  2017-01-01           1             1       2017
#
#       Station.City Station.Code Station.Location Station.State  \
# ...

# %%
df.drop(columns=["Station.Code", "Station.Location"])
# Out:
#        Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                    0.00  2016-01-03           1             3       2016
# 1                    0.00  2016-01-03           1             3       2016
# 2                    0.16  2016-01-03           1             3       2016
# 3                    0.00  2016-01-03           1             3       2016
# 4                    0.01  2016-01-03           1             3       2016
# ...                   ...         ...         ...           ...        ...
# 16738                0.08  2017-01-01           1             1       2017
# 16739                0.00  2017-01-01           1             1       2017
# 16740                0.00  2017-01-01           1             1       2017
# 16741                0.06  2017-01-01           1             1       2017
# 16742                0.10  2017-01-01           1             1       2017
#
#       Station.City Station.State  Data.Temperature.Avg Temp  \
# ...

# %%
pd.read_csv('C:\\Users\\admin\\Downloads\\weather.csv', header = 5)
# Out:
#        0.01  2016-01-03  1  3  2016 Anchorage  ANC Anchorage, AK   Alaska  34  \
# 0      0.09  2016-01-03  1  3  2016   Annette  ANN   Annette, AK   Alaska  38
# 1      0.05  2016-01-03  1  3  2016    Bethel  BET    Bethel, AK   Alaska  30
# 2      0.15  2016-01-03  1  3  2016   Bettles  BTT   Bettles, AK   Alaska  22
# 3      0.60  2016-01-03  1  3  2016  Cold Bay  CDB  Cold Bay, AK   Alaska  34
# 4      2.15  2016-01-03  1  3  2016   Cordova  CDV   Cordova, AK   Alaska  38
# ...     ...         ... .. ..   ...       ...  ...           ...      ...  ..
# 16733  0.08  2017-01-01  1  1  2017    Casper  CPR    Casper, WY  Wyoming  23
# 16734  0.00  2017-01-01  1  1  2017  Cheyenne  CYS  Cheyenne, WY  Wyoming  32
# 16735  0.00  2017-01-01  1  1  2017    Lander  LND    Lander, WY  Wyoming  17
# 16736  0.06  2017-01-01  1  1  2017   Rawlins  RWL   Rawlins, WY  Wyoming  23
# 16737  0.10  2017-01-01  1  1  2017  Sheridan  SHR  Sheridan, WY  Wyoming  21
#
#        38  29  19    7.8
# ...

# %%
df.describe()
# Out:
#        Data.Precipitation    Date.Month     Date.Year  \
# count        16743.000000  16743.000000  16743.000000
# mean             0.579090      6.343128   2016.018933
# std              0.988057      3.490723      0.136294
# min              0.000000      1.000000   2016.000000
# 25%              0.000000      3.000000   2016.000000
# 50%              0.190000      6.000000   2016.000000
# 75%              0.750000      9.000000   2016.000000
# max             20.890000     12.000000   2017.000000
#
#        Data.Temperature.Avg Temp  Data.Temperature.Max Temp  \
# count               16743.000000               16743.000000
# mean                   56.089112                  66.042406
# std                    18.798295                  19.787954
# min                   -27.000000                 -19.000000
# 25%                    44.000000                  53.000000
# 50%                    58.000000                  68.000000
# ...

# %%
sns.histplot(df['Data.Temperature.Avg Temp'], kde=True, bins=30)
plt.title('City')
plt.xlabel('State')
plt.ylabel('Model')
plt.show()

# %%
plt.plot(df['Date.Week of'], df['Data.Temperature.Avg Temp'])
plt.title("Line Graph Example")
plt.xlabel("X-axis Label")
plt.ylabel("Y-axis Label")
plt.show()

# %%
data=df["Data.Temperature.Avg Temp"]
plt.boxplot(data)  
plt.title("Box Plot")
plt.show()

# %%
import numpy as np
array = df['Station.City'].to_numpy()
array
# Out:
# array(['Birmingham', 'Huntsville', 'Mobile', ..., 'Lander', 'Rawlins',
#        'Sheridan'], dtype=object)

# %%
sorted_array = np.sort(array)
sorted_array
# Out:
# array(['Aberdeen', 'Aberdeen', 'Aberdeen', ..., 'Youngstown/Warren',
#        'Youngstown/Warren', 'Youngstown/Warren'], dtype=object)
